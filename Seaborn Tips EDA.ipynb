# %%
import seaborn as sns 
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.boxplot(x = df["total_bill"]);

# %%
sns.boxplot(x = df["total_bill"], orient = "v");
# Out:
# C:\Users\hardy\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
# ?sns.boxplot

# %%
#WHICH DAY TAKE MAX TOTAL BILL

# %%
sns.boxplot(x ="day", y ="total_bill", data =df);

# %%
#Dinner or Lunch is better ?

# %%
sns.boxplot(x ="time", y ="total_bill", data =df);

# %%
#Is the income directly proportional to the number of people in the groups that come to dinner?

# %%
sns.boxplot(x ="size", y ="total_bill", data =df);

# %%
sns.boxplot(x ="day", y ="total_bill", hue="sex", data =df);

# %%
sns.catplot(y="total_bill", kind="violin", data = df);

# %%
sns.catplot(y="total_bill", x= "day", kind="violin", data = df);

# %%
sns.catplot(y="total_bill",hue="sex", x= "day", kind="violin", data = df);

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df);

# %%
sns.scatterplot(x = "total_bill", hue = "time", y = "tip", data = df);

# %%
sns.scatterplot(x = "total_bill", hue = "time", y = "tip", data = df, style="time");

# %%
sns.scatterplot(x = "total_bill", hue = "day", y = "tip", data = df, style="time");

# %%
sns.scatterplot(x = "total_bill", hue = "day", y = "tip", data = df, style="day");

# %%
sns.scatterplot(x = "total_bill",  y = "tip", size = "size", data = df,);

# %%
sns.scatterplot(x = "total_bill", hue="size", y = "tip", size = "size", data = df,);

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df);

# %%
sns.lmplot(x = "total_bill",hue="smoker", y = "tip", data = df);

# %%
sns.lmplot(x = "total_bill",hue="smoker",col ="time", y = "tip", data = df);

# %%
sns.lmplot(x = "total_bill",hue="smoker",col ="time", row = "sex", y = "tip", data = df);
